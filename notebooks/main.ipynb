# %%
import sys
from PyQt5.QtWidgets import QApplication
from .gui import LiveGraphApp
from PyQt5.QtGui import QIcon


if __name__ == "__main__":
    app = QApplication(sys.argv)
    app.setWindowIcon(QIcon("assets//pepe-the-frog.ico"))
    window = LiveGraphApp()
    print("Application started with Python executable:", sys.executable)
    window.show()
    app.exec_()
# Out:
# Application started with Python executable: C:\Users\91961\AppData\Local\Programs\Python\Python312\python.exe
# Max Diff: 29.244678170128964
# Section Points: [0, 549, 890, 1215, 1568, 1939, 2635]
#  SegmentsF: [[0, 549], [549, 890], [890, 1215], [1215, 1568], [1568, 1939], [1939, 2635]]
# ... Offset set to: 664.8445257630387
# Initial Params: [678.9608439249092, 14.13961802804431, 0.0025, 0.0015]
# Fitted Params: [678.43996661  13.59544085   1.08701758  14.00314086]
# Initial Params: [695.8881707169091, 16.941350146345712, 0.0025, 0.0015]
# Fitted Params: [695.69328683  16.78894911   1.1752621   27.44666091]
# Initial Params: [715.2758140326446, 19.393171632521103, 0.0025, 0.0015]
# Fitted Params: [715.10041388  19.0359757    0.98718316  39.81218772]
# Initial Params: [732.3439967166166, 17.015539024200393, 0.0025, 0.0015]
# Fitted Params: [732.10751352  16.8811219    1.31054463  55.07352504]
# Initial Params: [761.908058964024, 29.77932457077452, 0.0025, 0.0015]
# Fitted Params: [761.60210264  29.57327784   1.19995814  68.46077363]
# Initial Params: [665.770113424448, -95.86370958690588, 0.0025, 0.0015]
# Fitted Params: [665.21058683 -95.96986754   2.22814999  81.67573183]
# Capture mode ON.
# Clicked at x = 0.7007109618587979
# Clicked at x = 12.370193801494391
# Current Sections: [[0.7007109618587979, 12.370193801494391]]
# Cal offset :  664.8354559890367
# Offset mode ON. Offset set to: 664.8445257630387
# Current Sections removed: []
# Offset mode OFF.
# Offset mode ON. Offset set to: 664.8445257630387
# Capture mode OFF.
# Capture mode ON.
# Clicked at x = 1.0653823005974101
# Clicked at x = 23.948508806445325
# Current Sections: [[1.0653823005974101, 23.948508806445325]]
# Clicked at x = 21.578145104644346
# Clicked at x = 36.347334323558144
# Current Sections: [[1.0653823005974101, 23.948508806445325], [21.578145104644346, 36.347334323558144]]
# Clicked at x = 34.52397762986508
# Clicked at x = 49.56667035283283
# Current Sections: [[1.0653823005974101, 23.948508806445325], [21.578145104644346, 36.347334323558144], [34.52397762986508, 49.56667035283283]]
# test  [1.0653823005974101, 23.948508806445325]
# test  [21.578145104644346, 36.347334323558144]
# test  [34.52397762986508, 49.56667035283283]
# Initial Params: [678.9513664500901, 14.049722601940516, 0.0025, 0.0015]
# Fitted Params: [678.58919966  13.74605363   1.02171593  13.98392213]
# Initial Params: [695.8881707169091, 17.034306595300563, 0.0025, 0.0015]
# Fitted Params: [695.69328022  16.78549216   1.17526985  27.44683822]
# Initial Params: [715.4556882321765, 19.369078071179615, 0.0025, 0.0015]
# Fitted Params: [715.099028    19.03258347   0.98754619  39.81240874]
# Current Sections removed: [[1.0653823005974101, 23.948508806445325], [21.578145104644346, 36.347334323558144]]
# Current Sections removed: [[1.0653823005974101, 23.948508806445325]]
# Current Sections removed: []
# No sections to remove
# Frames to copy at times (s): [1.0, 2.0]
# Copying: C:/Users/91961/Desktop/Jupyter 1/Spectra Analyser/Software/Real Time Analysis/18-08-2025/18-08-2025_Ag_50nm_bulk\Corrected Data\Frame0025.csv  to  C:/Users/91961/Desktop/Jupyter 1/Spectra Analyser/Software/Real Time Analysis/18-08-2025/18-08-2025_Ag_50nm_bulk\Selected Files\Frame0025.csv
# Copying: C:/Users/91961/Desktop/Jupyter 1/Spectra Analyser/Software/Real Time Analysis/18-08-2025/18-08-2025_Ag_50nm_bulk\Corrected Data\Frame0049.csv  to  C:/Users/91961/Desktop/Jupyter 1/Spectra Analyser/Software/Real Time Analysis/18-08-2025/18-08-2025_Ag_50nm_bulk\Selected Files\Frame0049.csv
